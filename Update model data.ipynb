# %% [markdown]
# # Update model data

# %% [markdown]
# ## Importing all the packages to be used in this notebook
#
# The following cell imports all the modules and functions required. Of note are `lines 18 - 20` which import the custom `electroninserts` functions. These custom functions are located within [electroninserts.py](../edit/electroninserts.py) which can be perused to ensure it is running as you would expect.

# %%
import os

import dicom

from glob import glob

import zipfile
import time
import shutil
import datetime
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from IPython.core.display import display, Markdown

from bokeh.io import output_notebook, output_file, reset_output
from bokeh.plotting import show, save

from electroninserts import (
    parameterise_single_insert, display_parameterisation,
    convert2_ratio_perim_area, interactive, fallback_scatter)

print("All modules and functions successfully imported.")
# Out:
# All modules and functions successfully imported.

# %%
# !pip install --upgrade version_information
# %load_ext version_information
# %version_information dicom, electroninserts, re, numpy, pandas, matplotlib, bokeh, version_information
# Out:
# Requirement already up-to-date: version_information in c:\users\sbiggs\appdata\local\continuum\anaconda3\envs\electroninserts\lib\site-packages
# Software versions
# Python 3.5.2 64bit [MSC v.1900 64 bit (AMD64)]
# IPython 5.0.0
# OS Windows 7 6.1.7601 SP1
# dicom 0.9.9
# electroninserts 0.1.0
# re 2.2.1
# numpy 1.11.1
# pandas 0.18.1
# matplotlib 1.5.1
# bokeh 0.11.1
# version_information 1.0.3
# Fri Aug 05 16:13:58 2016 AUS Eastern Standard Time

# %% [markdown]
# ## Recording and loading the data
# The following cells outline both your data itself the specific details of the data collection and definition. You can either write your own contents into the cells, or you can drag and drop the relevant files from your computer via windows explorer into the cell itself.
#
# Once you have input your data to please consider uploading this data to http://simonbiggs.net/electrondata for the purpose of furthering this project.

# %%
# Archive old files to minimise confusion
old_data_files = glob('*.csv')
old_detail_files = glob('*.yaml')
old_report_files = glob('*.html')
old_zip_files = glob('*.zip')

old_files = np.concatenate([
        old_data_files, old_detail_files, old_report_files, old_zip_files])

for data_file in old_files:
    os.rename(data_file, "archive/{}".format(data_file))

# %%
# %%writefile details.yaml
# %YAML 1.1
# ---
# Machine: Elekta Synergy Linac with Agility MLCs
#
# R50 (cm):
#     6 MeV: 2.45
#     9 MeV: 3.47
#     12 MeV: 4.72
#     15 MeV: 5.8
#     18 MeV: 7.2
#
# Applicator factors:
#     6 MeV:
#         6x6 cm: 0.871
#         10x10 cm: 1.000
#         14x14 cm: 1.029
#         20x20 cm: 1.022
#         25x25 cm: 1.026
#     9 MeV:
#         6x6 cm: 0.919
#         10x10 cm: 1.000
#         14x14 cm: 0.981
#         20x20 cm: 0.977
#         25x25 cm: 0.971
#     12 MeV:
#         6x6 cm: 0.971
#         10x10 cm: 1.000
#         14x14 cm: 0.990
#         20x20 cm: 0.985
#         25x25 cm: 0.983
#     15 MeV:
#         6x6 cm: 0.980
#         10x10 cm: 1.000
#         14x14 cm: 0.982
#         20x20 cm: 0.988
#         25x25 cm: 0.987
#     18 MeV:
#         6x6 cm: 1.011
#         10x10 cm: 1.000
#         14x14 cm: 0.983
#         20x20 cm: 0.979
#         25x25 cm: 0.967
#
# SSD factors:
#     100 SSD: 1.000
#
# Applicator sizes at isocentre:
#     6x6 cm: 6.3x6.3 cm
#     10x10 cm: 10.5x10.5 cm
#     14x14 cm: 14.7x14.7 cm
#     20x20 cm: 21.1x21.1 cm
#     25x25 cm: 26.3x26.3 cm
#
# Definition of modelled factor: >
#     The factor given here is the insert factor defined as the portion of the
#     electron output factor that is dependent on the insert alone. The electron
#     output factor is defined as per AAPM TG 25  as the ratio of dose per
#     monitor unit at dmax.
#
# Measurement details: >
#     Insert factors were measured in RW3 with an Advanced Markus on an Elekta
#     Agility linac. When the depth of maximum dose was shifted from the reference
#     depth this depth was searched for to a 1 mm resolution. All depth differences
#     took into account stopping power ratio corrections as per the protocol in
#     IAEA TRS 398.
#
# Insert shielding material: Cerrobend
#
# Software license of accompanying data: AGPLv3+
# Out:
# Writing details.yaml

# %%
# %%writefile data.csv
# Label,Width (cm @ 100SSD),Length (cm @ 100SSD),Energy (MeV),Applicator (cm),SSD (cm),Insert factor (dose insert / dose open)
# Simon 3cm circle,3.15,3.16,12,10,100,0.9294
# Simon 3x5cm oval,3.16,5.25,12,10,100,0.9346
# Simon 3x13cm oval,3.17,13.64,12,10,100,0.9533
# Simon 3x6.5cm oval,3.17,6.83,12,10,100,0.9488
# Simon 3x9cm oval,3.17,9.43,12,10,100,0.9488
# P4,3.55,7.7,12,10,100,0.9443
# Simon #57 cutout,3.66,5.04,12,10,100,0.9434
# Simon #112 cutout,3.71,4.36,12,10,100,0.9488
# Simon 4cm circle,4.2,4.21,12,10,100,0.956
# Simon 4x10cm oval,4.21,10.51,12,10,100,0.9709
# Simon 4x13cm oval,4.21,13.65,12,10,100,0.9756
# Simon 4x6.5cm oval,4.21,6.82,12,10,100,0.9606
# Simon 4x8cm oval,4.21,8.41,12,10,100,0.9709
# Simon #20 cutout,4.38,5.47,12,10,100,0.9634
# P10,4.48,7.29,12,10,100,0.9606
# Simon #14 cutout,4.59,5.67,12,10,100,0.9588
# Simon #3 cutout,4.59,6.54,12,10,100,0.9681
# Simon #38 cutout,4.67,6.28,12,10,100,0.9737
# Simon #22 cutout,5.21,11.4,12,10,100,0.9881
# Simon 5cm circle,5.25,5.26,12,10,100,0.9709
# Simon 5x10cm oval,5.26,10.52,12,10,100,0.9881
# Simon 5x13cm oval,5.26,13.66,12,10,100,0.9872
# Simon 5x8cm oval,5.26,8.41,12,10,100,0.9833
# Simon #104 cutout,5.34,9.64,12,10,100,0.993
# P40,5.43,11.02,12,10,100,0.9872
# Simon #19 cutout,5.72,11.6,12,10,100,0.999
# Simon #83 cutout,5.86,8.62,12,10,100,0.9891
# Simon #58 cutout,6,7.98,12,10,100,0.9911
# P3,6.04,9.22,12,10,100,0.999
# Simon #33 cutout,6.08,6.64,12,10,100,0.993
# Simon 6cm circle,6.3,6.33,12,10,100,0.9862
# Simon #43 cutout,6.31,8.24,12,10,100,0.9921
# Simon #82 cutout,6.41,8.69,12,10,100,0.999
# Simon #16 cutout,6.53,10.99,12,10,100,1
# Simon #109 cutout,6.54,8.41,12,10,100,0.993
# Simon #106 cutout,6.64,9.81,12,10,100,0.999
# Simon #34 cutout,6.78,10.98,12,10,100,1.007
# P22,6.9,10.25,12,10,100,0.999
# Simon #41 cutout,7.08,10.77,12,10,100,1.005
# Simon #6 cutout,7.18,11.27,12,10,100,0.999
# P38_1,7.21,9.03,12,10,100,1.0101
# Simon 7cm circle,7.36,7.37,12,10,100,1.003
# Simon #73 cutout,7.56,10.05,12,10,100,1.004
# P12_1,7.6,10.26,12,10,100,1.0142
# Simon #70 cutout,7.64,8.99,12,10,100,1.003
# Simon #18 cutout,7.82,10.85,12,10,100,1.002
# Simon #32 cutout,8.06,11.85,12,10,100,1.007
# Simon 8cm circle,8.4,8.42,12,10,100,1.007
# Simon 9cm circle,9.45,9.47,12,10,100,1.0081
# Simon 5cm_15MeV,4.99,5,15,10,100,0.9747
# P36_2,5.07,9.15,15,10,100,0.9911
# Simon 5.3x12.5cm_15MeV,5.26,12.45,15,10,100,0.9921
# Simon 6.1cm_15MeV,6.09,6.1,15,10,100,0.9794
# Simon 6.7x12cm_15MeV,6.76,12,15,10,100,0.999
# P5_2,6.97,9.79,15,10,100,0.996
# Simon 7.25cm_15MeV,7.23,7.26,15,10,100,1.003
# P28,7.4,9.25,15,10,100,1
# P37_1,7.73,9.66,15,10,100,1.005
# Simon 8.3cm_15MeV,8.28,8.3,15,10,100,1.005
# Simon 8.5x10.9cm_15MeV,8.5,10.85,15,10,100,1.005
# Simon 9.5cm_15MeV,9.49,9.5,15,10,100,1.0091
# P31_1,4.9,9.4,18,10,100,0.9911
# P36_1,4.9,9.4,18,10,100,0.994
# Simon 5cm_18MeV,4.99,5,18,10,100,0.9823
# Simon 5.3x12.5cm_18MeV,5.26,12.45,18,10,100,0.995
# Simon 6.1cm_18MeV,6.09,6.1,18,10,100,0.9881
# P37_4,6.67,9.28,18,10,100,1.0081
# Simon 6.7x12cm_18MeV,6.76,12,18,10,100,0.999
# P12_2,6.83,9.19,18,10,100,1.005
# P13,7.1,8.79,18,10,100,0.997
# Simon 7.25cm_18MeV,7.23,7.26,18,10,100,1.001
# Simon 8.3cm_18MeV,8.28,8.3,18,10,100,1.003
# Simon 8.5x10.9cm_18MeV,8.5,10.85,18,10,100,1.004
# P42,9.14,11.32,18,10,100,0.998
# Simon 9.5cm_18MeV,9.49,9.5,18,10,100,1.0081
# P62,3.99,6.51,6,10,100,0.9643
# P50,4.1,5.99,6,10,100,0.9662
# Simon 5cm_6MeV,4.99,5,6,10,100,0.9766
# Simon 5.3x12.5cm_6MeV,5.26,12.45,6,10,100,0.996
# P7,5.69,7.58,6,10,100,0.995
# Appears to be a standard 6cm P5_1,6,6,6,10,100,0.9887
# P9_1,5.79,7.2,6,10,100,0.9852
# Simon 6.1cm_6MeV,6.09,6.1,6,10,100,0.9901
# P24,6.47,8.25,6,10,100,0.995
# Simon 6.7x12cm_6MeV,6.76,12,6,10,100,0.998
# Simon 7.25cm_6MeV,7.23,7.26,6,10,100,1.007
# P35_2,7.43,10.3,6,10,100,0.994
# Simon 8.3cm_6MeV,8.28,8.3,6,10,100,1.006
# P6,8.5,10.73,6,10,100,0.999
# Simon 8.5x10.9cm_6MeV,8.5,10.85,6,10,100,1.003
# Simon 9.5cm_6MeV,9.49,9.5,6,10,100,1.005
# P46,4.37,6.21,9,10,100,0.9606
# Simon 5cm_9MeV,4.99,5,9,10,100,0.9588
# P53,5.09,6.32,9,10,100,0.9756
# Simon 5.3x12.5cm_9MeV,5.26,12.45,9,10,100,0.9901
# P25,5.38,8.23,9,10,100,0.9852
# P8,5.64,6.96,9,10,100,0.9775
# Simon 6.1cm_9MeV,6.09,6.1,9,10,100,0.9823
# P9_2,6.29,6.69,9,10,100,0.993
# P34_3,6.72,10.23,9,10,100,0.997
# Simon 6.7x12cm_9MeV,6.76,12,9,10,100,1
# Simon 7.25cm_9MeV,7.23,7.26,9,10,100,1.005
# Simon 8.3cm_9MeV,8.28,8.3,9,10,100,1.004
# P34_2,8.37,10.6,9,10,100,0.997
# Simon 8.5x10.9cm_9MeV,8.5,10.85,9,10,100,1.005
# P17,8.6,9.81,9,10,100,1.0111
# Simon 9.5cm_9MeV,9.49,9.5,9,10,100,1.007
# P61,4.69,14.39,12,14,100,0.9901
# P56,5.91,12.56,12,14,100,1.0091
# P15_1,7.4,13.47,12,14,100,1.0101
# P21,7.65,10.8,12,14,100,1.002
# P45,9.11,12.34,12,14,100,1.0091
# P19,7.08,8.84,15,14,100,1.0215
# P15_2,8.57,12.91,15,14,100,1.0215
# P27,9.25,11.42,15,14,100,1.0132
# P37_3,7.3,12.97,18,14,100,1.0132
# P38_2,8.69,11.49,18,14,100,1.0173
# P33,6.21,10.43,6,14,100,0.999
# P37_2,7.29,10.1,6,14,100,1.007
# P20,8.6,9.24,6,14,100,1.006
# P38_3,8.84,15.52,6,14,100,1.003
# P16,9.05,11.99,6,14,100,1.0111
# P35_1,9.28,10.58,6,14,100,1.0091
# P23,9.87,13.16,6,14,100,1.005
# P26,6.68,10.71,9,14,100,1.003
# P14_2,7.03,12.47,9,14,100,1.0173
# P34_1,7.66,11.25,9,14,100,1.006
# P18,8.6,10.32,9,14,100,1.0101
# P14_1,8.61,12.03,9,14,100,1.0163
# P31_2,10.65,17.74,18,20,100,1.0142
# P60,18.48,20.89,6,20,100,1.004
# P41,7.85,24.61,9,20,100,1.0111
# P32,9.3,22.7,9,20,100,1.0111
# P51,10,28.65,15,25,100,1.0142
# P49,2.69,4.21,6,6,100,0.8961
# P43,2.8,2.9,6,6,100,0.885
# P48,3.31,6.08,6,6,100,0.969
# P47,3.39,3.4,6,6,100,0.9083
# P35_3,3.48,4.78,6,6,100,0.939
# Standard 4cm circle P63,4,4,6,6,100,0.9425
# P59,4.1,5.89,6,6,100,0.9814
# Standard 5cm circle P29,5,5,6,6,100,0.9891
# P30,4.12,5.22,9,6,100,0.9597
# P2,4.43,5.97,9,6,100,0.9728
# P52,4.89,5.6,9,6,100,0.999
# Appears to be a standard 6cm P58,6,6,9,6,100,1.002
# P64,8.96,13.21,9,14,100,1.0121
# P65 parameterised by hand,8.4,10.7,15,14,100,1.003
# Out:
# Writing data.csv

# %% [markdown]
# ### Timestamping your data and details files and optionally uploading these for others to make use of
# Now that you have created your details and data files these are to be timestamped for later reference. Please consider giving back to this project by uncommenting the final lines of this cell which will add these two newly created files to this public dropbox folder &mdash; http://simonbiggs.net/electrondata. To uncomment these lines, select them and press `Ctrl + /`.

# %%
# Create a timestamp for data and reports and rename the data file
timestamp = datetime.datetime.fromtimestamp(time.time()).strftime('%Y%m%d%H%M%S')

data_filename = "{}_data.csv".format(timestamp)
details_filename = "{}_details.yaml".format(timestamp)
shutil.move("data.csv", data_filename)
shutil.move("details.yaml", details_filename)

# # Uncomment these lines to give back to this project
# import dropbox

# simonbiggs_electroninserts_accesstoken = '5_VQ4CH7dO0AAAAAAAAhYhsClbUdrEnWKvMMnWagVXqKDTlTdf45ZwlKBp6Q2Rhq'
# dpx = dropbox.dropbox.Dropbox(simonbiggs_electroninserts_accesstoken)
# with open(data_filename, 'rb') as file:
#     dpx.files_upload(file, "/{}".format(data_filename))
# with open(details_filename, 'rb') as file:
#     dpx.files_upload(file, "/{}".format(details_filename))
# Out:
# '20160805161358_details.yaml'

# %% [markdown]
# Once your csv has been created it can be loaded into a pandas DataFrame as such:

# %%
data = pd.read_csv(data_filename)
data
# Out:
#                                 Label  Width (cm @ 100SSD)  \
# 0                    Simon 3cm circle                 3.15
# 1                    Simon 3x5cm oval                 3.16
# 2                   Simon 3x13cm oval                 3.17
# 3                  Simon 3x6.5cm oval                 3.17
# 4                    Simon 3x9cm oval                 3.17
# 5                                  P4                 3.55
# 6                    Simon #57 cutout                 3.66
# 7                   Simon #112 cutout                 3.71
# 8                    Simon 4cm circle                 4.20
# 9                   Simon 4x10cm oval                 4.21
# 10                  Simon 4x13cm oval                 4.21
# 11                 Simon 4x6.5cm oval                 4.21
# 12                   Simon 4x8cm oval                 4.21
# 13                   Simon #20 cutout                 4.38
# 14                                P10                 4.48
# 15                   Simon #14 cutout                 4.59
# 16                    Simon #3 cutout                 4.59
# 17                   Simon #38 cutout                 4.67
# 18                   Simon #22 cutout                 5.21
# 19                   Simon 5cm circle                 5.25
# 20                  Simon 5x10cm oval                 5.26
# 21                  Simon 5x13cm oval                 5.26
# 22                   Simon 5x8cm oval                 5.26
# 23                  Simon #104 cutout                 5.34
# 24                                P40                 5.43
# 25                   Simon #19 cutout                 5.72
# 26                   Simon #83 cutout                 5.86
# 27                   Simon #58 cutout                 6.00
# 28                                 P3                 6.04
# 29                   Simon #33 cutout                 6.08
# ..                                ...                  ...
# 118                             P37_2                 7.29
# 119                               P20                 8.60
# 120                             P38_3                 8.84
# 121                               P16                 9.05
# 122                             P35_1                 9.28
# 123                               P23                 9.87
# 124                               P26                 6.68
# 125                             P14_2                 7.03
# 126                             P34_1                 7.66
# 127                               P18                 8.60
# 128                             P14_1                 8.61
# 129                             P31_2                10.65
# 130                               P60                18.48
# 131                               P41                 7.85
# 132                               P32                 9.30
# 133                               P51                10.00
# 134                               P49                 2.69
# 135                               P43                 2.80
# 136                               P48                 3.31
# 137                               P47                 3.39
# 138                             P35_3                 3.48
# 139           Standard 4cm circle P63                 4.00
# 140                               P59                 4.10
# 141           Standard 5cm circle P29                 5.00
# 142                               P30                 4.12
# 143                                P2                 4.43
# 144                               P52                 4.89
# 145  Appears to be a standard 6cm P58                 6.00
# 146                               P64                 8.96
# 147         P65 parameterised by hand                 8.40
#
#      Length (cm @ 100SSD)  Energy (MeV)  Applicator (cm)  SSD (cm)  \
# 0                    3.16            12               10       100
# 1                    5.25            12               10       100
# 2                   13.64            12               10       100
# 3                    6.83            12               10       100
# 4                    9.43            12               10       100
# 5                    7.70            12               10       100
# 6                    5.04            12               10       100
# 7                    4.36            12               10       100
# 8                    4.21            12               10       100
# 9                   10.51            12               10       100
# 10                  13.65            12               10       100
# 11                   6.82            12               10       100
# 12                   8.41            12               10       100
# 13                   5.47            12               10       100
# 14                   7.29            12               10       100
# 15                   5.67            12               10       100
# 16                   6.54            12               10       100
# 17                   6.28            12               10       100
# 18                  11.40            12               10       100
# 19                   5.26            12               10       100
# 20                  10.52            12               10       100
# 21                  13.66            12               10       100
# 22                   8.41            12               10       100
# 23                   9.64            12               10       100
# 24                  11.02            12               10       100
# 25                  11.60            12               10       100
# 26                   8.62            12               10       100
# 27                   7.98            12               10       100
# 28                   9.22            12               10       100
# 29                   6.64            12               10       100
# ..                    ...           ...              ...       ...
# 118                 10.10             6               14       100
# 119                  9.24             6               14       100
# 120                 15.52             6               14       100
# 121                 11.99             6               14       100
# 122                 10.58             6               14       100
# 123                 13.16             6               14       100
# 124                 10.71             9               14       100
# 125                 12.47             9               14       100
# 126                 11.25             9               14       100
# 127                 10.32             9               14       100
# 128                 12.03             9               14       100
# 129                 17.74            18               20       100
# 130                 20.89             6               20       100
# 131                 24.61             9               20       100
# 132                 22.70             9               20       100
# 133                 28.65            15               25       100
# 134                  4.21             6                6       100
# 135                  2.90             6                6       100
# 136                  6.08             6                6       100
# 137                  3.40             6                6       100
# 138                  4.78             6                6       100
# 139                  4.00             6                6       100
# 140                  5.89             6                6       100
# 141                  5.00             6                6       100
# 142                  5.22             9                6       100
# 143                  5.97             9                6       100
# 144                  5.60             9                6       100
# 145                  6.00             9                6       100
# 146                 13.21             9               14       100
# 147                 10.70            15               14       100
#
#      Insert factor (dose insert / dose open)
# 0                                     0.9294
# 1                                     0.9346
# 2                                     0.9533
# 3                                     0.9488
# 4                                     0.9488
# 5                                     0.9443
# 6                                     0.9434
# 7                                     0.9488
# 8                                     0.9560
# 9                                     0.9709
# 10                                    0.9756
# 11                                    0.9606
# 12                                    0.9709
# 13                                    0.9634
# 14                                    0.9606
# 15                                    0.9588
# 16                                    0.9681
# 17                                    0.9737
# 18                                    0.9881
# 19                                    0.9709
# 20                                    0.9881
# 21                                    0.9872
# 22                                    0.9833
# 23                                    0.9930
# 24                                    0.9872
# 25                                    0.9990
# 26                                    0.9891
# 27                                    0.9911
# 28                                    0.9990
# 29                                    0.9930
# ..                                       ...
# 118                                   1.0070
# 119                                   1.0060
# 120                                   1.0030
# 121                                   1.0111
# 122                                   1.0091
# 123                                   1.0050
# 124                                   1.0030
# 125                                   1.0173
# 126                                   1.0060
# 127                                   1.0101
# 128                                   1.0163
# 129                                   1.0142
# 130                                   1.0040
# 131                                   1.0111
# 132                                   1.0111
# 133                                   1.0142
# 134                                   0.8961
# 135                                   0.8850
# 136                                   0.9690
# 137                                   0.9083
# 138                                   0.9390
# 139                                   0.9425
# 140                                   0.9814
# 141                                   0.9891
# 142                                   0.9597
# 143                                   0.9728
# 144                                   0.9990
# 145                                   1.0020
# 146                                   1.0121
# 147                                   1.0030
#
# [148 rows x 7 columns]

# %% [markdown]
# Singling out a single energy, applicator, ssd is as simple as the following:

# %%
energy = 6
applicator = 10
ssd = 100

reference = (
    (data['Energy (MeV)'] == energy) &
    (data['Applicator (cm)'] == applicator) &
    (data['SSD (cm)'] == ssd)
)

data[reference]
# Out:
#                                 Label  Width (cm @ 100SSD)  \
# 75                                P62                 3.99
# 76                                P50                 4.10
# 77                     Simon 5cm_6MeV                 4.99
# 78              Simon 5.3x12.5cm_6MeV                 5.26
# 79                                 P7                 5.69
# 80  Appears to be a standard 6cm P5_1                 6.00
# 81                               P9_1                 5.79
# 82                   Simon 6.1cm_6MeV                 6.09
# 83                                P24                 6.47
# 84                Simon 6.7x12cm_6MeV                 6.76
# 85                  Simon 7.25cm_6MeV                 7.23
# 86                              P35_2                 7.43
# 87                   Simon 8.3cm_6MeV                 8.28
# 88                                 P6                 8.50
# 89              Simon 8.5x10.9cm_6MeV                 8.50
# 90                   Simon 9.5cm_6MeV                 9.49
#
#     Length (cm @ 100SSD)  Energy (MeV)  Applicator (cm)  SSD (cm)  \
# 75                  6.51             6               10       100
# 76                  5.99             6               10       100
# 77                  5.00             6               10       100
# 78                 12.45             6               10       100
# 79                  7.58             6               10       100
# 80                  6.00             6               10       100
# 81                  7.20             6               10       100
# 82                  6.10             6               10       100
# 83                  8.25             6               10       100
# 84                 12.00             6               10       100
# 85                  7.26             6               10       100
# 86                 10.30             6               10       100
# 87                  8.30             6               10       100
# 88                 10.73             6               10       100
# 89                 10.85             6               10       100
# 90                  9.50             6               10       100
#
#     Insert factor (dose insert / dose open)
# 75                                   0.9643
# 76                                   0.9662
# 77                                   0.9766
# 78                                   0.9960
# 79                                   0.9950
# 80                                   0.9887
# 81                                   0.9852
# 82                                   0.9901
# 83                                   0.9950
# 84                                   0.9980
# 85                                   1.0070
# 86                                   0.9940
# 87                                   1.0060
# 88                                   0.9990
# 89                                   1.0030
# 90                                   1.0050

# %% [markdown]
# It is also possible to test if a given combination has sufficient data:

# %%
number_of_data = len(data[reference])
print("Number of data = {}".format(number_of_data))

number_of_data >= 8
# Out:
# Number of data = 16
# True

# %% [markdown]
# ## Displaying model report given applicator / energy / ssd combination

# %%
reset_output()
output_notebook()

energy = 6
applicator = 10
ssd = 100

reference = (
    (data['Energy (MeV)'] == energy) &
    (data['Applicator (cm)'] == applicator) &
    (data['SSD (cm)'] == ssd)
)

input_dataframe = data[reference]

label = np.array(input_dataframe['Label']).astype(str)
width_data = np.array(input_dataframe['Width (cm @ 100SSD)']).astype(float)
length_data = np.array(input_dataframe['Length (cm @ 100SSD)']).astype(float)
factor_data = np.array(input_dataframe['Insert factor (dose insert / dose open)']).astype(float)
ratio_perim_area_data = convert2_ratio_perim_area(width_data, length_data)

figure = interactive(
    width_data, length_data, ratio_perim_area_data, factor_data, label)
show(figure)
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="f522df3a-782c-4b31-910b-82055f80754e">Loading BokehJS ...</span>
#     </div>
#     <div class="plotdiv" id="395b96b9-6167-40a3-bb8f-4c0e48662017"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("395b96b9-6167-40a3-bb8f-4c0e48662017");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '395b96b9-6167-40a3-bb8f-4c0e48662017' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"13b0ec44-94b9-407c-a6fd-51e351cdfaac":{"roots":{"references":[{"attributes":{},"id":"ec1e1e3a-0dda-44b6-a841-36ca64b69cd5","type":"StringFormatter"},{"attributes":{},"id":"48f15981-4f15-405a-94af-d06cc7b61d33","type":"StringFormatter"},{"attributes":{},"id":"c7139ed9-18ed-4e66-8d2a-8b28dd0b98d7","type":"StringFormatter"},{"attributes":{"axis_label":"Width (cm)","formatter":{"id":"6fdde23f-9138-4b98-a0c1-bbf7c15e3995","type":"BasicTickFormatter"},"plot":{"id":"0f7003ec-941c-49af-afba-1bf8a87a2c54","subtype":"Figure","type":"Plot"},"ticker":{"id":"6f307d1f-7c85-4b26-9585-cc7190b03c33","type":"BasicTicker"}},"id":"6e36f6d6-1240-4beb-9749-8d80d2a62b64","type":"LinearAxis"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"694c8c37-bbad-4a2c-9be7-ec5ef324158c","type":"BoxAnnotation"},{"attributes":{"fill_color":{"field":"colour"},"size":{"units":"screen","value":10},"x":{"field":"width"},"y":{"field":"ratio_perim_area"}},"id":"20780ca1-af76-405c-b001-dc83eb84f9e5","type":"Circle"},{"attributes":{},"id":"40978d96-871d-4bc6-8c91-bdb90cd57c84","type":"BasicTickFormatter"},{"attributes":{"callback":null,"end":9.721000000000007,"start":3.5790000000000015},"id":"421d3bd0-1c13-46a8-8cec-8b262abb13cc","type":"Range1d"},{"attributes":{"callback":null,"plot":{"id":"332d1fb8-7794-496d-a85c-03a2a4a6bb88","subtype":"Figure","type":"Plot"}},"id":"e396cc91-4425-485f-8967-5fbaeea72ba1","type":"TapTool"},{"attributes":{},"id":"d418fa26-2f95-449c-9d16-2e604c016e96","type":"ToolEvents"},{"attributes":{},"id":"be1f394d-a370-4030-98f3-bc17f8243d8f","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"field":"width"},"y":{"field":"length"}},"id":"823bebc7-778b-47d7-8d2b-de7a5f53f255","type":"Circle"},{"attributes":{},"id":"4a4d3c51-cde9-418d-b06f-7b7c51a76728","type":"StringFormatter"},{"attributes":{"callback":null,"overlay":{"id":"a7bea38b-9883-4fe0-a0ab-ee80a130bce2","type":"BoxAnnotation"},"plot":{"id":"0f7003ec-941c-49af-afba-1bf8a87a2c54","subtype":"Figure","type":"Plot"},"renderers":[{"id":"dfa834ca-9af8-4b1e-8768-faccb7b76c61","type":"GlyphRenderer"},{"id":"1a6fe347-3e68-48b7-b482-54feb5208cfe","type":"GlyphRenderer"},{"id":"ad8763d1-9456-4b83-b5e7-dfc1d7e053f0","type":"GlyphRenderer"}]},"id":"37ddf5c6-44e4-46e3-96dd-acce457f902f","type":"BoxSelectTool"},{"attributes":{"editor":{"id":"2636b464-7947-4125-93a4-00b23f00ac92","type":"StringEditor"},"field":"model_value","formatter":{"id":"e0442d31-1680-4d34-b710-b46258f27a71","type":"StringFormatter"},"title":"Model factor"},"id":"b64f1d70-7973-4b89-981d-b415166d2bf2","type":"TableColumn"},{"attributes":{"children":[[{"id":"332d1fb8-7794-496d-a85c-03a2a4a6bb88","subtype":"Figure","type":"Plot"},{"id":"5f2c9331-eaac-4b75-a719-002285b408e0","subtype":"Figure","type":"Plot"},{"id":"0f7003ec-941c-49af-afba-1bf8a87a2c54","subtype":"Figure","type":"Plot"}]],"toolbar_location":null},"id":"f1a7672e-6ab9-48cc-af76-eb778a94ea6f","type":"GridPlot"},{"attributes":{"grid_line_color":{"value":null},"plot":{"id":"332d1fb8-7794-496d-a85c-03a2a4a6bb88","subtype":"Figure","type":"Plot"},"ticker":{"id":"bffde5df-ad89-4ece-be98-b2f9231cc114","type":"BasicTicker"}},"id":"32cc8b17-bac9-47a1-aed1-e7d4226bbd2b","type":"Grid"},{"attributes":{"fill_color":{"field":"colour"},"size":{"units":"screen","value":10},"x":{"field":"width"},"y":{"field":"length"}},"id":"a164d91a-0671-4d91-b21a-56417ac6a7e0","type":"Circle"},{"attributes":{"callback":null},"id":"12bf51b9-5333-4174-856e-bb3f9da5f7c9","type":"DataRange1d"},{"attributes":{"fill_alpha":{"value":0},"fill_color":{"value":"# ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[10]</strong>&gt;</code></p>

# %%
reset_output()
output_notebook()
# output_file("test.html", title="test")

energy = 9
applicator = 6
ssd = 100

reference = (
    (data['Energy (MeV)'] == energy) &
    (data['Applicator (cm)'] == applicator) &
    (data['SSD (cm)'] == ssd)
)

input_dataframe = data[reference]

label = np.array(input_dataframe['Label']).astype(str)
width_data = np.array(input_dataframe['Width (cm @ 100SSD)']).astype(float)
length_data = np.array(input_dataframe['Length (cm @ 100SSD)']).astype(float)
factor_data = np.array(input_dataframe['Insert factor (dose insert / dose open)']).astype(float)

figure = fallback_scatter(width_data, length_data, factor_data, label)

show(figure)
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="b166e26c-6f7f-4575-89a8-1a4bd981c7d5">Loading BokehJS ...</span>
#     </div>
#     <div class="plotdiv" id="c8a34e64-e08f-4ba6-be20-f7b552ea3694"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c8a34e64-e08f-4ba6-be20-f7b552ea3694");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c8a34e64-e08f-4ba6-be20-f7b552ea3694' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"28fc320b-458a-4af1-866b-845d3b8bd0e7":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"007976e2-d3b4-4696-801d-8c9271f866ec","type":"BoxAnnotation"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"1b71a89f-fda6-47eb-90aa-3be1a16e6598","type":"Circle"},{"attributes":{"callback":null,"column_names":["Label","Width","Length","Factor","y","x"],"data":{"Factor":[" 0.960"," 0.973"," 0.999"," 1.002"],"Label":["P30","P2","P52","Appears to be a standard 6cm P58"],"Length":[" 5.2 cm"," 6.0 cm"," 5.6 cm"," 6.0 cm"],"Width":[" 4.1 cm"," 4.4 cm"," 4.9 cm"," 6.0 cm"],"x":[4.12,4.43,4.89,6.0],"y":[0.9597,0.9728,0.9990000000000001,1.002]}},"id":"bb2517ca-48c2-4fcb-b3e1-991c24ad5002","type":"ColumnDataSource"},{"attributes":{"callback":null},"id":"a4fc47f2-c6e5-4c69-bd8c-453af62dcb5f","type":"DataRange1d"},{"attributes":{"overlay":{"id":"007976e2-d3b4-4696-801d-8c9271f866ec","type":"BoxAnnotation"},"plot":{"id":"d6858251-ae0e-4f90-9007-262d3ea85049","subtype":"Figure","type":"Plot"}},"id":"3d1764af-9f88-4a65-b836-257f12028139","type":"BoxZoomTool"},{"attributes":{"below":[{"id":"3af08202-a6aa-4665-88ad-427c82aee0d3","type":"LinearAxis"}],"left":[{"id":"d5854d2e-a280-4ca0-8bb8-b7033758ced9","type":"LinearAxis"}],"plot_height":400,"renderers":[{"id":"3af08202-a6aa-4665-88ad-427c82aee0d3","type":"LinearAxis"},{"id":"272e5f93-e790-405f-81e2-350af896f839","type":"Grid"},{"id":"d5854d2e-a280-4ca0-8bb8-b7033758ced9","type":"LinearAxis"},{"id":"bf739b61-65f6-46bc-95ab-4cef2e41efca","type":"Grid"},{"id":"007976e2-d3b4-4696-801d-8c9271f866ec","type":"BoxAnnotation"},{"id":"0baaf70d-dbee-4919-8b82-1e5bdcde5c18","type":"GlyphRenderer"}],"title":"Fallback scatter plot","tool_events":{"id":"eda43900-8e22-419c-b09c-a4dba053e14b","type":"ToolEvents"},"tools":[{"id":"ed84205d-73e3-4ecb-a4e8-bc8b4123ce65","type":"HoverTool"},{"id":"3d1764af-9f88-4a65-b836-257f12028139","type":"BoxZoomTool"},{"id":"9accd467-6176-4604-a4a1-da74b12ded0c","type":"ResetTool"}],"x_range":{"id":"f7f65837-33de-44c7-b4c2-e123cb7a0110","type":"DataRange1d"},"y_range":{"id":"a4fc47f2-c6e5-4c69-bd8c-453af62dcb5f","type":"DataRange1d"}},"id":"d6858251-ae0e-4f90-9007-262d3ea85049","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"71814fb1-b4f7-45b1-903a-44251900e1ca","type":"BasicTicker"},{"attributes":{},"id":"1b53fe85-e295-4d3f-ba85-7c9f4aee0390","type":"BasicTickFormatter"},{"attributes":{"dimension":1,"plot":{"id":"d6858251-ae0e-4f90-9007-262d3ea85049","subtype":"Figure","type":"Plot"},"ticker":{"id":"2fb1d3e8-43b5-4603-932b-33634587fb42","type":"BasicTicker"}},"id":"bf739b61-65f6-46bc-95ab-4cef2e41efca","type":"Grid"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"13ef4c52-376e-41a7-bbe8-7306e6677543","type":"Circle"},{"attributes":{},"id":"eda43900-8e22-419c-b09c-a4dba053e14b","type":"ToolEvents"},{"attributes":{"data_source":{"id":"bb2517ca-48c2-4fcb-b3e1-991c24ad5002","type":"ColumnDataSource"},"glyph":{"id":"13ef4c52-376e-41a7-bbe8-7306e6677543","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"1b71a89f-fda6-47eb-90aa-3be1a16e6598","type":"Circle"},"selection_glyph":null},"id":"0baaf70d-dbee-4919-8b82-1e5bdcde5c18","type":"GlyphRenderer"},{"attributes":{},"id":"2fb1d3e8-43b5-4603-932b-33634587fb42","type":"BasicTicker"},{"attributes":{"axis_label":"Factor","formatter":{"id":"8efbf851-094a-4c04-9453-4d0c690a4696","type":"BasicTickFormatter"},"plot":{"id":"d6858251 ...
#             var render_items = [{"docid":"28fc320b-458a-4af1-866b-845d3b8bd0e7","elementid":"c8a34e64-e08f-4ba6-be20-f7b552ea3694","modelid":"d6858251-ae0e-4f90-9007-262d3ea85049","notebook_comms_target":"621f4e99-2fe7-42db-b26d-a23d13b56d50"}];
#
#             Bokeh.embed.embed_items(docs_json, render_items);
#         });
#       },
#       function(Boke
# <p><code>&lt;Bokeh Notebook handle for <strong>In[11]</strong>&gt;</code></p>

# %% [markdown]
# ## Creating reports

# %%
energy_array = np.unique(data['Energy (MeV)'])
applicator_array = np.unique(data['Applicator (cm)'])
ssd_array = np.unique(data['SSD (cm)'])

print("Iterate over the following scenarios:")
print("Energy = {}".format(energy_array))
print("Applicator = {}".format(applicator_array))
print("SSD = {}".format(ssd_array))
# Out:
# Iterate over the following scenarios:
# Energy = [ 6  9 12 15 18]
# Applicator = [ 6 10 14 20 25]
# SSD = [100]

# %%
# reset_output()
# output_notebook()

for energy in energy_array:
    for applicator in applicator_array:
        for ssd in ssd_array:
            
            reference = (
                (data['Energy (MeV)'] == energy) &
                (data['Applicator (cm)'] == applicator) &
                (data['SSD (cm)'] == ssd)
            )
            
            input_dataframe = data[reference]
            label = np.array(input_dataframe['Label']).astype(str)
            width_data = np.array(
                input_dataframe['Width (cm @ 100SSD)']).astype(float)
            length_data = np.array(
                input_dataframe['Length (cm @ 100SSD)']).astype(float)
            factor_data = np.array(
                input_dataframe['Insert factor (dose insert / dose open)']).astype(float)
            
            number_of_data = len(input_dataframe)
            filename = "{}_{}energy_{}applicator_{}ssd_{}data.html".format(
                timestamp, str(energy).zfill(2), str(applicator).zfill(2), 
                str(ssd).zfill(3), str(number_of_data).zfill(2))
            title = "{}MeV | {}App | {}SSD".format(
                energy, applicator, ssd)
            
            reset_output()
            output_file(filename, title=title)
            
            if number_of_data >= 8:
                ratio_perim_area_data = convert2_ratio_perim_area(width_data, length_data)

                figure = interactive(
                    width_data, length_data, ratio_perim_area_data, factor_data, label)
            else:
                figure = fallback_scatter(width_data, length_data, factor_data, label)
                
            save(figure)

# %%
created_reports = glob("{}*.html".format(timestamp))
zip_filename = '{}_reports.zip'.format(timestamp)

with zipfile.ZipFile(zip_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
    for file in created_reports:
        zipf.write(file)
    
    zipf.write(details_filename)
    zipf.write(data_filename)

display(Markdown("[To download reports: `Right click me > Save link as...`]({}_reports.zip)".format(timestamp)))
# Out:
# [To download reports: `Right click me > Save link as...`](20160805161358_reports.zip)

# %% [markdown]
# ## Copyright information
# Copyright &#169; 2016  Simon Biggs
#
# This program is free software: you can redistribute it and/or modify
# it under the terms of the GNU Affero General Public License as published
# by the Free Software Foundation, either version 3 of the License, or
# (at your option) any later version.
#
# This program is distributed in the hope that it will be useful,
# but WITHOUT ANY WARRANTY; without even the implied warranty of
# MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.  See the
# GNU Affero General Public License for more details.
#
# You should have received a copy of the GNU Affero General Public License
# along with this program.  If not, see <http://www.gnu.org/licenses/>.
